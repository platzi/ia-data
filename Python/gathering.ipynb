# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://techcrunch.com/'

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

posts = soup.find_all('div', class_='post-block post-block--image post-block--unread')

data = []

for post in posts:
    title = post.find('h2', class_='post-block__title').text.strip()
    link = post.find('a', class_='post-block__title__link')['href']
    date = post.find('time', class_='river-byline__time')['datetime']
    author = post.find('span', class_='river-byline__authors').text.strip()
    content = post.find('div', class_='post-block__content').text.strip()

    data.append({
        'title': title,
        'link': link,
        'date': date,
        'author': author,
        'content': content,
    })

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                                                title  \
# 0  DeepMind repurposes game-playing AIs to optimi...
# 1  Minecraft is releasing a new version for Chrom...
# 2  Meta Verified arrives in India, now honors ‘le...
# 3  TikTok expands its ‘Series’ paywall feature to...
# 4  Register for today’s TechCrunch Live’s event o...
#
#                                                 link  \
# 0  https://techcrunch.com/2023/06/07/deepmind-rep...
# 1  https://techcrunch.com/2023/06/07/minecraft-is...
# 2  https://techcrunch.com/2023/06/07/meta-verifie...
# 3  https://techcrunch.com/2023/06/07/tiktok-expan...
# 4  https://techcrunch.com/2023/06/07/register-for...
#
#                         date            author  \
# 0  2023-06-07T08:01:05-07:00    Devin Coldewey
# 1  2023-06-07T08:00:52-07:00        Ivan Mehta
# 2  2023-06-07T07:56:44-07:00       Sarah Perez
# 3  2023-06-07T07:25:33-07:00  Lauren Forristal
# 4  2023-06-07T07:08:17-07:00        Matt Burns
#
#                                              content
# 0  DeepMind’s Alpha series of AIs has provided a ...
# 1  Minecraft is releasing an early access version...
# 2  Meta Verified, the Facebook and Instagram owne...
# 3  Previously only available to select content cr...
# 4  TechCrunch Live is excited to host a special, ...

# %%
# escribe una funcion para separar la fecha de la hora en dos columnas diferentes, de la columna "date"

def split_date(date):
    date = date.split('T')
    return date[0], date[1]

df['date'], df['time'] = zip(*df['date'].map(split_date))

# %%
df.head()
# Out:
#                                                title  \
# 0  DeepMind repurposes game-playing AIs to optimi...
# 1  Minecraft is releasing a new version for Chrom...
# 2  Meta Verified arrives in India, now honors ‘le...
# 3  TikTok expands its ‘Series’ paywall feature to...
# 4  Register for today’s TechCrunch Live’s event o...
#
#                                                 link        date  \
# 0  https://techcrunch.com/2023/06/07/deepmind-rep...  2023-06-07
# 1  https://techcrunch.com/2023/06/07/minecraft-is...  2023-06-07
# 2  https://techcrunch.com/2023/06/07/meta-verifie...  2023-06-07
# 3  https://techcrunch.com/2023/06/07/tiktok-expan...  2023-06-07
# 4  https://techcrunch.com/2023/06/07/register-for...  2023-06-07
#
#              author                                            content  \
# 0    Devin Coldewey  DeepMind’s Alpha series of AIs has provided a ...
# 1        Ivan Mehta  Minecraft is releasing an early access version...
# 2       Sarah Perez  Meta Verified, the Facebook and Instagram owne...
# 3  Lauren Forristal  Previously only available to select content cr...
# 4        Matt Burns  TechCrunch Live is excited to host a special, ...
#
#              time
# 0  08:01:05-07:00
# 1  08:00:52-07:00
# 2  07:56:44-07:00
# 3  07:25:33-07:00
# 4  07:08:17-07:00

# %%
## Crea una funcion para eliminar duplicados y reemplazar los valores nulos por 'N/A' en el dataframe df 

def clean_df(df):
    df = df.drop_duplicates()
    df = df.fillna('N/A')
    return df

df = clean_df(df)

# %%
df.head()
# Out:
#                                                title  \
# 0  DeepMind repurposes game-playing AIs to optimi...
# 1  Minecraft is releasing a new version for Chrom...
# 2  Meta Verified arrives in India, now honors ‘le...
# 3  TikTok expands its ‘Series’ paywall feature to...
# 4  Register for today’s TechCrunch Live’s event o...
#
#                                                 link        date  \
# 0  https://techcrunch.com/2023/06/07/deepmind-rep...  2023-06-07
# 1  https://techcrunch.com/2023/06/07/minecraft-is...  2023-06-07
# 2  https://techcrunch.com/2023/06/07/meta-verifie...  2023-06-07
# 3  https://techcrunch.com/2023/06/07/tiktok-expan...  2023-06-07
# 4  https://techcrunch.com/2023/06/07/register-for...  2023-06-07
#
#              author                                            content  \
# 0    Devin Coldewey  DeepMind’s Alpha series of AIs has provided a ...
# 1        Ivan Mehta  Minecraft is releasing an early access version...
# 2       Sarah Perez  Meta Verified, the Facebook and Instagram owne...
# 3  Lauren Forristal  Previously only available to select content cr...
# 4        Matt Burns  TechCrunch Live is excited to host a special, ...
#
#              time
# 0  08:01:05-07:00
# 1  08:00:52-07:00
# 2  07:56:44-07:00
# 3  07:25:33-07:00
# 4  07:08:17-07:00
